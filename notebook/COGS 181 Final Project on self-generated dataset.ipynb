# %% [markdown]
# # COGS 181 Final Project on self-generated dataset
#
# ### Yushan Wang A14459085
# ### Jiemin Tang A13948547

# %% [markdown]
# ### Import package

# %%
from __future__ import print_function
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

import os
import cv2
import matplotlib.pyplot as plt
import numpy as np
from random import shuffle
from random import randint

# It should print "Using TensorFlow backend"
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ### Helper function

# %%
def imshow(inp, title=None):
    inp = inp.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    inp = std * inp + mean
    inp = np.clip(inp, 0, 1)
    plt.figure(figsize=(20,20))
    plt.imshow(inp)

    if title is not None:
        plt.title(title)
    plt.pause(0.001)

# %% [markdown]
# ### Initialize path directories for dataset

# %%
# paths for thw two dataset folders
mask = r'dataset/with_mask'
no_mask = r'dataset/without_mask'

# %% [markdown]
# ### Load and Store images

# %%
width = 160
height = 160
dim = (width, height)
images = []
for file in list(os.listdir(mask)):
    img = cv2.imread(mask+'/'+file)
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    images.append(img)
    
for file in list(os.listdir(no_mask)):
    img = cv2.imread(no_mask+'/'+file)
    img = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
    images.append(img) 
    
images = np.array(images)

# %% [markdown]
# ### One-hot encoding for mask/no-mask

# %%
# store labels (mask = 1,0 and  no mask = 0,1)
n_mask = len(list(os.listdir(mask)))
n_no_mask = len(list(os.listdir(no_mask)))
labels = np.zeros(( n_mask  + n_no_mask, 2  ))
labels[:n_mask,0] = 1
labels[n_mask:,1] = 1
print('y shape',labels.shape)   #(1376, 2)
print('x shape',images.shape)   #(1376, 160, 160, 3)
# Out:
# y shape (1376, 2)
# x shape (1376, 160, 160, 3)

# %% [markdown]
# ### shuffle and split data

# %%
data_size = labels.shape[0]
index = list(range(data_size))
shuffle(index)
index = np.array(index)
images =   images[index]
labels =   labels[index,:]
x_train =  images[:int(0.8*data_size)]
y_train =  labels[:int(0.8*data_size),:] 

x_test =   images[int(0.8*data_size):]
y_test =   labels[int(0.8*data_size):,:]

# %% [markdown]
# ### Preview data
# #### Show random image with corresponding label

# %%
rand_int = randint(0, len(x_test))
plt.imshow(x_test[rand_int][:,:,::-1])
print((np.array(['With Mask','Without Mask'])[y_test[rand_int] == 1])[0])
# Out:
# With Mask

# %% [markdown]
# ### Initialize model parameters

# %%
img_rows, img_cols = images.shape[1], images.shape[2]
input_shape = (images.shape[1], images.shape[2], images.shape[3])
batch_size = 1
num_classes = 2

# %% [markdown]
# ### Create Model

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(num_classes, activation='softmax'))

# compile the model
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 158, 158, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 79, 79, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 77, 77, 32)        9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 38, 38, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 36, 36, 64)        18496
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 18, 18, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 18, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 20736)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                1327168
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 66
# =================================================================
# Total params: 1,357,954
# Trainable params: 1,357,954
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          verbose=1,
          validation_data=(x_test, y_test))
# Out:
# Train on 1100 samples, validate on 276 samples
# Epoch 1/15
# 1100/1100 [==============================] - 61s 55ms/step - loss: 1.4431 - accuracy: 0.5745 - val_loss: 0.7390 - val_accuracy: 0.5362
# Epoch 2/15
# 1100/1100 [==============================] - 65s 59ms/step - loss: 0.8863 - accuracy: 0.5327 - val_loss: 0.6760 - val_accuracy: 0.5543
# Epoch 3/15
# 1100/1100 [==============================] - 65s 59ms/step - loss: 0.6489 - accuracy: 0.6282 - val_loss: 0.6189 - val_accuracy: 0.6558
# Epoch 4/15
# 1100/1100 [==============================] - 61s 56ms/step - loss: 0.6539 - accuracy: 0.6718 - val_loss: 0.5442 - val_accuracy: 0.7391
# Epoch 5/15
# 1100/1100 [==============================] - 65s 59ms/step - loss: 0.7040 - accuracy: 0.6455 - val_loss: 0.5829 - val_accuracy: 0.6884
# Epoch 6/15
# 1100/1100 [==============================] - 64s 58ms/step - loss: 0.6095 - accuracy: 0.8027 - val_loss: 0.2968 - val_accuracy: 0.9384
# Epoch 7/15
# 1100/1100 [==============================] - 67s 61ms/step - loss: 0.3359 - accuracy: 0.8691 - val_loss: 0.2816 - val_accuracy: 0.8949
# Epoch 8/15
# 1100/1100 [==============================] - 63s 57ms/step - loss: 0.2020 - accuracy: 0.9318 - val_loss: 0.1461 - val_accuracy: 0.9601
# Epoch 9/15
# 1100/1100 [==============================] - 64s 58ms/step - loss: 0.1049 - accuracy: 0.9682 - val_loss: 0.1300 - val_accuracy: 0.9710
# Epoch 10/15
# 1100/1100 [==============================] - 61s 56ms/step - loss: 0.1024 - accuracy: 0.9764 - val_loss: 0.0695 - val_accuracy: 0.9674
# Epoch 11/15
# 1100/1100 [==============================] - 64s 58ms/step - loss: 0.0830 - accuracy: 0.9845 - val_loss: 1.3741 - val_accuracy: 0.7029
# Epoch 12/15
# 1100/1100 [==============================] - 63s 58ms/step - loss: 0.1732 - accuracy: 0.9645 - val_loss: 0.4828 - val_accuracy: 0.8333
# Epoch 13/15
# 1100/1100 [==============================] - 65s 59ms/step - loss: 0.1058 - accuracy: 0.9691 - val_loss: 0.1229 - val_accuracy: 0.9674
# Epoch 14/15
# 1100/1100 [==============================] - 68s 62ms/step - loss: 0.0580 - accuracy: 0.9800 - val_loss: 0.1382 - val_accuracy: 0.9710
# Epoch 15/15
# 1100/1100 [==============================] - 62s 57ms/step - loss: 0.0857 - accuracy: 0.9791 - val_loss: 0.1107 - val_accuracy: 0.9710

# %% [markdown]
# ### Evaluate the model

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.11074489684424539
# Test accuracy: 0.9710144996643066

# %% [markdown]
# ### Test the model

# %%
rand = randint(0, 270)
m = model.predict(x_test[rand].reshape(-1,160,160,3)) == model.predict(x_test[rand].reshape(-1,160,160,3)).max()
plt.imshow(x_test[rand][:,:,::-1])
print(np.array(['With Mask','Without Mask'])[m[0]])
# Out:
# ['Without Mask']

# %% [markdown]
# ### Save the model

# %%
modelsave_name = 'SELF_DATASET_face_mask.h5'
model.save(modelsave_name)
